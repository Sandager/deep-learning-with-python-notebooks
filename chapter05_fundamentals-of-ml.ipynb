# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Fundamentals of machine learning

# %% [markdown]
# ## Generalization: The goal of machine learning

# %% [markdown]
# ### Underfitting and overfitting

# %% [markdown]
# #### Noisy training data

# %% [markdown]
# #### Ambiguous features

# %% [markdown]
# #### Rare features and spurious correlations

# %% [markdown]
# **Adding white-noise channels or all-zeros channels to MNIST**

# %%
from tensorflow.keras.datasets import mnist
import numpy as np

(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

train_images_with_noise_channels = np.concatenate(
    [train_images, np.random.random((len(train_images), 784))], axis=1)

train_images_with_zeros_channels = np.concatenate(
    [train_images, np.zeros((len(train_images), 784))], axis=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **Training the same model on MNIST data with noise channels or all-zero channels**

# %%
from tensorflow import keras
from tensorflow.keras import layers

def get_model():
    model = keras.Sequential([
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])
    model.compile(optimizer="rmsprop",
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    return model

model = get_model()
history_noise = model.fit(
    train_images_with_noise_channels, train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2)

model = get_model()
history_zeros = model.fit(
    train_images_with_zeros_channels, train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.6947 - loss: 1.0406 - val_accuracy: 0.9062 - val_loss: 0.3066
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9111 - loss: 0.2845 - val_accuracy: 0.9255 - val_loss: 0.2322
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.9480 - loss: 0.1712 - val_accuracy: 0.9462 - val_loss: 0.1710
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9649 - loss: 0.1157 - val_accuracy: 0.9603 - val_loss: 0.1354
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9732 - loss: 0.0855 - val_accuracy: 0.9567 - val_loss: 0.1436
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9799 - loss: 0.0640 - val_accuracy: 0.9646 - val_loss: 0.1161
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9856 - loss: 0.0455 - val_accuracy: 0.9545 - val_loss: 0.1692
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9885 - loss: 0.0348 - val_accuracy: 0.9647 - val_loss: 0.1280
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9930 - loss: 0.0234 - val_accuracy: 0.9672 - val_loss: 0.1256
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9944 - loss: 0.0186 - val_accuracy: 0.9686 - val_loss: 0.1265
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8572 - loss: 0.4903 - val_accuracy: 0.9572 - val_loss: 0.1509
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9608 - loss: 0.1317 - val_accuracy: 0.9639 - val_loss: 0.1228
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9759 - loss: 0.0833 - val_accuracy: 0.9747 - val_loss: 0.0849
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9832 - loss: 0.0600 - val_accuracy: 0.9748 - val_loss: 0.0823
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9868 - loss: 0.0443 - val_accuracy: 0.9772 - val_loss: 0.0770
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9913 - loss: 0.0301 - val_accuracy: 0.9762 - val_loss: 0.0793
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9936 - loss: 0.0239 - val_accuracy: 0.9795 - val_loss: 0.0707
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9951 - loss: 0.0182 - val_accuracy: 0.9800 - val_loss: 0.0728
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.9969 - loss: 0.0128 - val_accuracy: 0.9807 - val_loss: 0.0693
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9980 - loss: 0.0099 - val_accuracy: 0.9816 - val_loss: 0.0714

# %% [markdown]
# **Plotting a validation accuracy comparison**

# %%
import matplotlib.pyplot as plt
val_acc_noise = history_noise.history["val_accuracy"]
val_acc_zeros = history_zeros.history["val_accuracy"]
epochs = range(1, 11)
plt.plot(epochs, val_acc_noise, "b-",
         label="Validation accuracy with noise channels")
plt.plot(epochs, val_acc_zeros, "b--",
         label="Validation accuracy with zeros channels")
plt.title("Effect of noise channels on validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# ### The nature of generalization in deep learning

# %% [markdown]
# **Fitting a MNIST model with randomly shuffled labels**

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

random_train_labels = train_labels[:]
np.random.shuffle(random_train_labels)

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, random_train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1048 - loss: 2.3291 - val_accuracy: 0.1028 - val_loss: 2.3066
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1212 - loss: 2.2972 - val_accuracy: 0.1054 - val_loss: 2.3134
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.1294 - loss: 2.2885 - val_accuracy: 0.1046 - val_loss: 2.3170
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1425 - loss: 2.2742 - val_accuracy: 0.1001 - val_loss: 2.3311
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.1606 - loss: 2.2568 - val_accuracy: 0.1020 - val_loss: 2.3315
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1699 - loss: 2.2388 - val_accuracy: 0.1018 - val_loss: 2.3494
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.1875 - loss: 2.2141 - val_accuracy: 0.0990 - val_loss: 2.3693
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.2004 - loss: 2.1864 - val_accuracy: 0.1001 - val_loss: 2.3838
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2169 - loss: 2.1536 - val_accuracy: 0.1035 - val_loss: 2.4024
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2382 - loss: 2.1198 - val_accuracy: 0.1023 - val_loss: 2.4230

# %% [markdown]
# #### The manifold hypothesis

# %% [markdown]
# #### Interpolation as a source of generalization

# %% [markdown]
# #### Why deep learning works

# %% [markdown]
# #### Training data is paramount

# %% [markdown]
# ## Evaluating machine-learning models

# %% [markdown]
# ### Training, validation, and test sets

# %% [markdown]
# #### Simple hold-out validation

# %% [markdown]
# #### K-fold validation

# %% [markdown]
# #### Iterated K-fold validation with shuffling

# %% [markdown]
# ### Beating a common-sense baseline

# %% [markdown]
# ### Things to keep in mind about model evaluation

# %% [markdown]
# ## Improving model fit

# %% [markdown]
# ### Tuning key gradient descent parameters

# %% [markdown]
# **Training a MNIST model with an incorrectly high learning rate**

# %%
(train_images, train_labels), _ = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255

model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer=keras.optimizers.RMSprop(1.),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.4435 - loss: 2582.5664 - val_accuracy: 0.2170 - val_loss: 2.3218
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2084 - loss: 7.5027 - val_accuracy: 0.1354 - val_loss: 2.4957
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.1618 - loss: 2.4970 - val_accuracy: 0.1633 - val_loss: 2.3410
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.1857 - loss: 2.4282 - val_accuracy: 0.1873 - val_loss: 2.4295
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1844 - loss: 2.3761 - val_accuracy: 0.1667 - val_loss: 2.2257
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1567 - loss: 2.4177 - val_accuracy: 0.2192 - val_loss: 2.1398
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.2164 - loss: 2.2662 - val_accuracy: 0.1784 - val_loss: 2.2169
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.1900 - loss: 2.2970 - val_accuracy: 0.2052 - val_loss: 2.2173
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.2018 - loss: 2.3306 - val_accuracy: 0.2138 - val_loss: 2.1791
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.1994 - loss: 2.3087 - val_accuracy: 0.2416 - val_loss: 2.2518

# %% [markdown]
# **The same model with a more appropriate learning rate**

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])
model.compile(optimizer=keras.optimizers.RMSprop(1e-2),
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
model.fit(train_images, train_labels,
          epochs=10,
          batch_size=128,
          validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8361 - loss: 0.7609 - val_accuracy: 0.9534 - val_loss: 0.1536
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9630 - loss: 0.1271 - val_accuracy: 0.9576 - val_loss: 0.1800
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9750 - loss: 0.0935 - val_accuracy: 0.9683 - val_loss: 0.1439
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9801 - loss: 0.0717 - val_accuracy: 0.9653 - val_loss: 0.1862
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9843 - loss: 0.0594 - val_accuracy: 0.9731 - val_loss: 0.1594
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9862 - loss: 0.0499 - val_accuracy: 0.9689 - val_loss: 0.2073
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9876 - loss: 0.0502 - val_accuracy: 0.9665 - val_loss: 0.2293
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9886 - loss: 0.0463 - val_accuracy: 0.9741 - val_loss: 0.1848
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9913 - loss: 0.0362 - val_accuracy: 0.9730 - val_loss: 0.2298
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9907 - loss: 0.0381 - val_accuracy: 0.9714 - val_loss: 0.2385

# %% [markdown]
# ### Leveraging better architecture priors

# %% [markdown]
# ### Increasing model capacity

# %% [markdown]
# **A simple logistic regression on MNIST**

# %%
model = keras.Sequential([layers.Dense(10, activation="softmax")])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_small_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7387 - loss: 1.0331 - val_accuracy: 0.9044 - val_loss: 0.3580
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8999 - loss: 0.3675 - val_accuracy: 0.9147 - val_loss: 0.3089
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9117 - loss: 0.3234 - val_accuracy: 0.9180 - val_loss: 0.2934
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9143 - loss: 0.3056 - val_accuracy: 0.9204 - val_loss: 0.2840
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9182 - loss: 0.2932 - val_accuracy: 0.9241 - val_loss: 0.2774
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9207 - loss: 0.2827 - val_accuracy: 0.9253 - val_loss: 0.2739
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9219 - loss: 0.2773 - val_accuracy: 0.9261 - val_loss: 0.2723
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9203 - loss: 0.2811 - val_accuracy: 0.9278 - val_loss: 0.2693
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9248 - loss: 0.2776 - val_accuracy: 0.9277 - val_loss: 0.2676
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9246 - loss: 0.2733 - val_accuracy: 0.9277 - val_loss: 0.2663
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9240 - loss: 0.2744 - val_accuracy: 0.9281 - val_loss: 0.2673
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9265 - loss: 0.2662 - val_accuracy: 0.9277 - val_loss: 0.2665
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9277 - loss: 0.2621 - val_accuracy: 0.9283 - val_loss: 0.2649
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9285 - loss: 0.2594 - val_accuracy: 0.9270 - val_loss: 0.2662
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9284 - loss: 0.2587 - val_accuracy: 0.9285 - val_loss: 0.2638
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9283 - loss: 0.2615 - val_accuracy: 0.9290 - val_loss: 0.2641
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9273 - loss: 0.2612 - val_accuracy: 0.9287 - val_loss: 0.2648
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9283 - loss: 0.2668 - val_accuracy: 0.9289 - val_loss: 0.2651
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9298 - loss: 0.2610 - val_accuracy: 0.9294 - val_loss: 0.2641
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9293 - loss: 0.2555 - val_accuracy: 0.9300 - val_loss: 0.2637

# %%
import matplotlib.pyplot as plt
val_loss = history_small_model.history["val_loss"]
epochs = range(1, 21)
plt.plot(epochs, val_loss, "b--",
         label="Validation loss")
plt.title("Effect of insufficient model capacity on validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
model = keras.Sequential([
    layers.Dense(96, activation="relu"),
    layers.Dense(96, activation="relu"),
    layers.Dense(10, activation="softmax"),
])
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])
history_large_model = model.fit(
    train_images, train_labels,
    epochs=20,
    batch_size=128,
    validation_split=0.2)
# Out:
# Epoch 1/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8260 - loss: 0.6302 - val_accuracy: 0.9473 - val_loss: 0.1862
# Epoch 2/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9473 - loss: 0.1799 - val_accuracy: 0.9592 - val_loss: 0.1413
# Epoch 3/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9637 - loss: 0.1236 - val_accuracy: 0.9660 - val_loss: 0.1166
# Epoch 4/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9719 - loss: 0.0930 - val_accuracy: 0.9685 - val_loss: 0.1125
# Epoch 5/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9786 - loss: 0.0691 - val_accuracy: 0.9706 - val_loss: 0.1039
# Epoch 6/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9820 - loss: 0.0593 - val_accuracy: 0.9713 - val_loss: 0.1046
# Epoch 7/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9850 - loss: 0.0491 - val_accuracy: 0.9691 - val_loss: 0.1094
# Epoch 8/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9878 - loss: 0.0404 - val_accuracy: 0.9715 - val_loss: 0.1020
# Epoch 9/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9892 - loss: 0.0341 - val_accuracy: 0.9736 - val_loss: 0.1002
# Epoch 10/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9909 - loss: 0.0291 - val_accuracy: 0.9718 - val_loss: 0.1090
# Epoch 11/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9922 - loss: 0.0248 - val_accuracy: 0.9744 - val_loss: 0.1063
# Epoch 12/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9941 - loss: 0.0196 - val_accuracy: 0.9716 - val_loss: 0.1096
# Epoch 13/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9957 - loss: 0.0157 - val_accuracy: 0.9728 - val_loss: 0.1163
# Epoch 14/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9952 - loss: 0.0155 - val_accuracy: 0.9736 - val_loss: 0.1168
# Epoch 15/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9751 - val_loss: 0.1201
# Epoch 16/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9728 - val_loss: 0.1282
# Epoch 17/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9974 - loss: 0.0085 - val_accuracy: 0.9737 - val_loss: 0.1292
# Epoch 18/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9980 - loss: 0.0071 - val_accuracy: 0.9734 - val_loss: 0.1338
# Epoch 19/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9741 - val_loss: 0.1343
# Epoch 20/20
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9983 - loss: 0.0051 - val_accuracy: 0.9738 - val_loss: 0.1409

# %% [markdown]
# ## Improving generalization

# %% [markdown]
# ### Dataset curation

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# ### Using early stopping

# %% [markdown]
# ### Regularizing your model

# %% [markdown]
# #### Reducing the network's size

# %% [markdown]
# **Original model**

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results
train_data = vectorize_sequences(train_data)

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_original = model.fit(train_data, train_labels,
                             epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7107 - loss: 0.5970 - val_accuracy: 0.8558 - val_loss: 0.4024
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8834 - loss: 0.3459 - val_accuracy: 0.8747 - val_loss: 0.3228
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9162 - loss: 0.2490 - val_accuracy: 0.8879 - val_loss: 0.2860
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9344 - loss: 0.1960 - val_accuracy: 0.8859 - val_loss: 0.2832
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9518 - loss: 0.1575 - val_accuracy: 0.8868 - val_loss: 0.2835
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9600 - loss: 0.1334 - val_accuracy: 0.8872 - val_loss: 0.2857
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9662 - loss: 0.1133 - val_accuracy: 0.8842 - val_loss: 0.2968
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9751 - loss: 0.0963 - val_accuracy: 0.8785 - val_loss: 0.3330
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.9770 - loss: 0.0872 - val_accuracy: 0.8781 - val_loss: 0.3421
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9818 - loss: 0.0694 - val_accuracy: 0.8813 - val_loss: 0.3506
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9861 - loss: 0.0603 - val_accuracy: 0.8801 - val_loss: 0.3703
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9875 - loss: 0.0538 - val_accuracy: 0.8778 - val_loss: 0.3919
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9905 - loss: 0.0440 - val_accuracy: 0.8744 - val_loss: 0.4235
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9934 - loss: 0.0356 - val_accuracy: 0.8745 - val_loss: 0.4342
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9950 - loss: 0.0291 - val_accuracy: 0.8732 - val_loss: 0.4574
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9956 - loss: 0.0261 - val_accuracy: 0.8739 - val_loss: 0.4847
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9957 - loss: 0.0238 - val_accuracy: 0.8726 - val_loss: 0.5078
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9965 - loss: 0.0203 - val_accuracy: 0.8730 - val_loss: 0.5267
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9986 - loss: 0.0142 - val_accuracy: 0.8595 - val_loss: 0.6124
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9946 - loss: 0.0241 - val_accuracy: 0.8677 - val_loss: 0.5969

# %% [markdown]
# **Version of the model with lower capacity**

# %%
model = keras.Sequential([
    layers.Dense(4, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_smaller_model = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6386 - loss: 0.6598 - val_accuracy: 0.8377 - val_loss: 0.5355
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8650 - loss: 0.4909 - val_accuracy: 0.8668 - val_loss: 0.4260
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8948 - loss: 0.3777 - val_accuracy: 0.8776 - val_loss: 0.3608
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9136 - loss: 0.3057 - val_accuracy: 0.8824 - val_loss: 0.3209
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9237 - loss: 0.2575 - val_accuracy: 0.8865 - val_loss: 0.2972
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9316 - loss: 0.2221 - val_accuracy: 0.8903 - val_loss: 0.2827
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9410 - loss: 0.1903 - val_accuracy: 0.8865 - val_loss: 0.2812
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9467 - loss: 0.1734 - val_accuracy: 0.8877 - val_loss: 0.2758
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.9577 - loss: 0.1476 - val_accuracy: 0.8875 - val_loss: 0.2813
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9585 - loss: 0.1386 - val_accuracy: 0.8904 - val_loss: 0.2784
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9661 - loss: 0.1205 - val_accuracy: 0.8869 - val_loss: 0.2854
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9704 - loss: 0.1061 - val_accuracy: 0.8866 - val_loss: 0.2905
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9727 - loss: 0.1009 - val_accuracy: 0.8843 - val_loss: 0.3050
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9760 - loss: 0.0890 - val_accuracy: 0.8800 - val_loss: 0.3256
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9799 - loss: 0.0787 - val_accuracy: 0.8834 - val_loss: 0.3199
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9830 - loss: 0.0706 - val_accuracy: 0.8817 - val_loss: 0.3317
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.9867 - loss: 0.0614 - val_accuracy: 0.8814 - val_loss: 0.3431
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.9897 - loss: 0.0536 - val_accuracy: 0.8788 - val_loss: 0.3538
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9903 - loss: 0.0489 - val_accuracy: 0.8790 - val_loss: 0.3772
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9910 - loss: 0.0455 - val_accuracy: 0.8765 - val_loss: 0.3829

# %% [markdown]
# **Version of the model with higher capacity**

# %%
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(512, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_larger_model = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 320ms/step - accuracy: 0.6837 - loss: 0.6362 - val_accuracy: 0.8434 - val_loss: 0.3673
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 326ms/step - accuracy: 0.8501 - loss: 0.3509 - val_accuracy: 0.8229 - val_loss: 0.4187
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 0.9012 - loss: 0.2465 - val_accuracy: 0.8880 - val_loss: 0.2668
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 303ms/step - accuracy: 0.9322 - loss: 0.1822 - val_accuracy: 0.8813 - val_loss: 0.3012
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 297ms/step - accuracy: 0.9431 - loss: 0.1438 - val_accuracy: 0.8572 - val_loss: 0.3728
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 306ms/step - accuracy: 0.9656 - loss: 0.0966 - val_accuracy: 0.8867 - val_loss: 0.3262
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 336ms/step - accuracy: 0.9743 - loss: 0.0829 - val_accuracy: 0.8574 - val_loss: 0.4742
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 301ms/step - accuracy: 0.9853 - loss: 0.0508 - val_accuracy: 0.8833 - val_loss: 0.3207
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 13s 382ms/step - accuracy: 0.9979 - loss: 0.0185 - val_accuracy: 0.8823 - val_loss: 0.4239
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 266ms/step - accuracy: 0.9864 - loss: 0.0591 - val_accuracy: 0.8816 - val_loss: 0.3814
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 328ms/step - accuracy: 0.9994 - loss: 0.0077 - val_accuracy: 0.8823 - val_loss: 0.4570
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 0.8832 - val_loss: 0.5214
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 304ms/step - accuracy: 0.9883 - loss: 0.0584 - val_accuracy: 0.8818 - val_loss: 0.4329
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 291ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8829 - val_loss: 0.5089
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 12s 341ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8810 - val_loss: 0.5735
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 283ms/step - accuracy: 1.0000 - loss: 8.5640e-04 - val_accuracy: 0.8841 - val_loss: 0.6244
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - accuracy: 1.0000 - loss: 5.1813e-04 - val_accuracy: 0.8832 - val_loss: 0.6628
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 11s 331ms/step - accuracy: 1.0000 - loss: 3.3016e-04 - val_accuracy: 0.8830 - val_loss: 0.6817
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 9s 289ms/step - accuracy: 1.0000 - loss: 2.5373e-04 - val_accuracy: 0.8816 - val_loss: 0.6984
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 1.0000 - loss: 2.1510e-04 - val_accuracy: 0.8812 - val_loss: 0.7169

# %% [markdown]
# #### Adding weight regularization

# %% [markdown]
# **Adding L2 weight regularization to the model**

# %%
from tensorflow.keras import regularizers
model = keras.Sequential([
    layers.Dense(16,
                 kernel_regularizer=regularizers.l2(0.002),
                 activation="relu"),
    layers.Dense(16,
                 kernel_regularizer=regularizers.l2(0.002),
                 activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_l2_reg = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.7123 - loss: 0.7012 - val_accuracy: 0.8544 - val_loss: 0.5118
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8796 - loss: 0.4660 - val_accuracy: 0.8812 - val_loss: 0.4134
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9072 - loss: 0.3675 - val_accuracy: 0.8764 - val_loss: 0.3916
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9259 - loss: 0.3136 - val_accuracy: 0.8862 - val_loss: 0.3657
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9300 - loss: 0.2929 - val_accuracy: 0.8857 - val_loss: 0.3623
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9345 - loss: 0.2757 - val_accuracy: 0.8861 - val_loss: 0.3597
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9393 - loss: 0.2644 - val_accuracy: 0.8847 - val_loss: 0.3603
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9439 - loss: 0.2519 - val_accuracy: 0.8838 - val_loss: 0.3622
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9487 - loss: 0.2409 - val_accuracy: 0.8820 - val_loss: 0.3659
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9550 - loss: 0.2335 - val_accuracy: 0.8814 - val_loss: 0.3687
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9541 - loss: 0.2285 - val_accuracy: 0.8813 - val_loss: 0.3743
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9594 - loss: 0.2209 - val_accuracy: 0.8817 - val_loss: 0.3756
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9582 - loss: 0.2184 - val_accuracy: 0.8817 - val_loss: 0.3782
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9608 - loss: 0.2176 - val_accuracy: 0.8766 - val_loss: 0.3917
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9584 - loss: 0.2156 - val_accuracy: 0.8791 - val_loss: 0.3874
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9633 - loss: 0.2067 - val_accuracy: 0.8636 - val_loss: 0.4387
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9596 - loss: 0.2110 - val_accuracy: 0.8729 - val_loss: 0.4070
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.9604 - loss: 0.2061 - val_accuracy: 0.8776 - val_loss: 0.3958
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9687 - loss: 0.1951 - val_accuracy: 0.8772 - val_loss: 0.4000
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9605 - loss: 0.2031 - val_accuracy: 0.8651 - val_loss: 0.4560

# %% [markdown]
# **Different weight regularizers available in Keras**

# %%
from tensorflow.keras import regularizers
regularizers.l1(0.001)
regularizers.l1_l2(l1=0.001, l2=0.001)

# %% [markdown]
# #### Adding dropout

# %% [markdown]
# **Adding dropout to the IMDB model**

# %%
model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(16, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])
history_dropout = model.fit(
    train_data, train_labels,
    epochs=20, batch_size=512, validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.5693 - loss: 0.6693 - val_accuracy: 0.8382 - val_loss: 0.5247
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7263 - loss: 0.5471 - val_accuracy: 0.8728 - val_loss: 0.4018
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.7831 - loss: 0.4610 - val_accuracy: 0.8692 - val_loss: 0.3561
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8184 - loss: 0.4029 - val_accuracy: 0.8859 - val_loss: 0.3075
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8638 - loss: 0.3426 - val_accuracy: 0.8878 - val_loss: 0.2891
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8834 - loss: 0.2992 - val_accuracy: 0.8849 - val_loss: 0.2846
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9068 - loss: 0.2619 - val_accuracy: 0.8892 - val_loss: 0.2744
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9252 - loss: 0.2309 - val_accuracy: 0.8898 - val_loss: 0.2866
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9339 - loss: 0.2056 - val_accuracy: 0.8899 - val_loss: 0.2971
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9424 - loss: 0.1850 - val_accuracy: 0.8878 - val_loss: 0.3101
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.9472 - loss: 0.1664 - val_accuracy: 0.8892 - val_loss: 0.3253
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9562 - loss: 0.1518 - val_accuracy: 0.8868 - val_loss: 0.3416
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9619 - loss: 0.1310 - val_accuracy: 0.8862 - val_loss: 0.3511
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9599 - loss: 0.1241 - val_accuracy: 0.8861 - val_loss: 0.3634
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9653 - loss: 0.1128 - val_accuracy: 0.8817 - val_loss: 0.4279
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9670 - loss: 0.1072 - val_accuracy: 0.8848 - val_loss: 0.4282
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9733 - loss: 0.0908 - val_accuracy: 0.8846 - val_loss: 0.4479
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9718 - loss: 0.0916 - val_accuracy: 0.8826 - val_loss: 0.4793
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9745 - loss: 0.0797 - val_accuracy: 0.8839 - val_loss: 0.5173
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9761 - loss: 0.0787 - val_accuracy: 0.8813 - val_loss: 0.5646

# %% [markdown]
# ## Summary
